# %% [markdown]
# ##### ARTI 560 - Computer Vision
#
# ## Vision and Language (Multimodal AI with CLIP) - Exercise

# %% [markdown]
# ### Exercise 1:
# A major factor in CLIP's performance is **how** the text prompts are structured. For example, passing just the word `"dog"` usually performs worse than using a template like `"a photo of a dog"`.
#
# **Task:**
# 1. Use the $32 \times 32$ CIFAR-100 image.
#    `url = "http://images.cocodataset.org/val2017/000000039769.jpg"`
# 2. Compare three different prompt styles:
#    * **Style A (Raw labels):** `["cat", "dog", "butterfly", ...]`
#    * **Style B (Standard template):** `["a photo of a cat", "a photo of a dog", ...]`
#    * **Style C (Domain-specific template):** `["a low-resolution, blurry photo of a tiny cat", "a low-resolution, blurry photo of a tiny dog", ...]`
# 3. Print out and compare the confidence percentage assigned to the correct ground-truth class across all three styles. Which one performed the best, and why?

# %%
# Provide your solution here

# %% [markdown]
# ### Exercise 2:
# CLIP models are excellent at identifying overall concepts present in an image, but they famously struggle with **compositional logic** (e.g., identifying relative positioning like "left of", "inside", or negative attributes like "no cats").
#
# **Task:**
# 1. Find or download an image that clearly displays a specific relationship (for example: **a red apple sitting next to a green banana**).
# 2. Create a targeted list of candidate labels that deliberately mix up the composition, such as:
#    * `"a red apple and a green banana"` (Correct)
#    * `"a green apple and a red banana"` (Color Swap)
#    * `"a banana on top of an apple"` (Spatial Position Swap)
#    * `"a photo containing no apples"` (Negation)
# 3. Run the image and text candidate array through CLIP and analyze the resulting probabilities. Does the model successfully capture fine-grained logic, or does it just look at individual word matching?

# %%
# Provide your solution here
